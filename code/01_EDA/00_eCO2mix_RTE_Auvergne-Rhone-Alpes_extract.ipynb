# %%
import pandas as pd
import boto3
from dotenv import load_dotenv
import os
import io

# %%
# Chargement API KEYS
load_dotenv()

API_KEY_S3 = os.environ["API_KEY_S3"]
API_SECRET_KEY_S3 = os.environ["API_SECRET_KEY_S3"]

bucket_name = "renergies99-lead-bucket"
s3_prefix = "public"

# %%
# Session Boto3
session = boto3.Session(
    aws_access_key_id=API_KEY_S3,
    aws_secret_access_key=API_SECRET_KEY_S3,
    region_name="eu-west-3",
)

s3 = session.resource("s3")
bucket = s3.Bucket(bucket_name)

# Dossier S3 avec données
national_prefix = f"{s3_prefix}/prod/unzipped/regional/"

# Lister les objets S3 sous ce préfixe
xlsx_keys = sorted(
    obj.key
    for obj in bucket.objects.filter(Prefix=national_prefix)
    if obj.key.endswith(".xlsx")
)

print(f"{len(xlsx_keys)} fichiers trouvés sur S3")

# 2. Charger et concaténer
dfs = []
for key in xlsx_keys:
    s3_obj = s3.Object(bucket_name, key).get()
    buffer = io.BytesIO(s3_obj["Body"].read())

    df = pd.read_excel(buffer)  # ici seulement xlsx → pas besoin de gérer xls
    dfs.append(df)

df_all = pd.concat(dfs, ignore_index=True)

print(df_all.shape)
df_all.head()
# Out:
# 5 fichiers trouvés sur S3
# (171023, 67)
#               Périmètre              Nature       Date    Heures  \
# 0  Auvergne-Rhône-Alpes  Données temps réel 2025-01-01  00:00:00
# 1  Auvergne-Rhône-Alpes  Données temps réel 2025-01-01  00:15:00
# 2  Auvergne-Rhône-Alpes  Données temps réel 2025-01-01  00:30:00
# 3  Auvergne-Rhône-Alpes  Données temps réel 2025-01-01  00:45:00
# 4  Auvergne-Rhône-Alpes  Données temps réel 2025-01-01  01:00:00
#
#    Consommation  Thermique  Nucléaire  Eolien  Solaire  Hydraulique  ...  \
# 0        9002.0      134.0    11017.0   118.0      0.0       2609.0  ...
# 1        9023.0      134.0    10976.0   130.0      0.0       2473.0  ...
# 2        8940.0      133.0    10733.0   137.0      0.0       2454.0  ...
# 3        8803.0      125.0    10399.0   140.0      0.0       2345.0  ...
# 4        8802.0      126.0    10137.0   151.0      0.0       2319.0  ...
#
#    TCO Nucléaire (%)  TCH Nucléaire (%) TCO Eolien (%) TCH Eolien (%)  \
# 0             122.38              81.19           1.31          15.92
# 1             121.64              80.88           1.44          17.54
# 2             120.06              79.09           1.53          18.49
# 3             118.13              76.63           1.59          18.89
# 4             115.17              74.70           1.72          20.38
#
#   TCO Solaire (%) TCH Solaire (%)  TCO Hydraulique (%) TCH Hydraulique (%)  \
# 0               0             0.0                28.98               22.88
# 1               0             0.0                27.41               21.69
# 2               0             0.0                27.45               21.52
# 3               0             0.0                26.64               20.57
# 4               0             0.0                26.35               20.34
#
#   TCO Bioénergies (%) TCH Bioénergies (%)
# 0                0.44               21.16
# 1                0.44               21.16
# 2                0.45               21.16
# 3                0.45               21.16
# 4                0.45               21.16
#
# [5 rows x 67 columns]

# %%
df_all = df_all[~df_all["Heures"].astype(str).str.endswith(("15:00", "45:00"))]

# %%
# Sélection automatique des colonnes TCO... (%) ou TCH... (%) si besoin
cols_pct = [c for c in df_all.columns if "TCO" in c or "TCH" in c]

# Conversion en float
df_all[cols_pct] = df_all[cols_pct].apply(
    lambda col: pd.to_numeric(col, errors="coerce")
)

# %%
# Convertir le DataFrame en CSV et résidant en mémoire
csv_buffer = io.StringIO()
df_all.to_csv(csv_buffer, index=False, encoding="utf-8")

# Upload direct sur S3
s3_key = "public/prod/eCO2mix_RTE_Auvergne-Rhone-Alpes.csv"

s3.Object(bucket_name, s3_key).put(Body=csv_buffer.getvalue())

print(f"CSV envoyé sur s3://{bucket_name}/{s3_key}")
# Out:
# CSV envoyé sur s3://renergies99-bucket/public/prod/eCO2mix_RTE_Auvergne-Rhone-Alpes.csv

# %%
df_all.shape
# Out:
# (85514, 67)

# %%
df_all.head()
# Out:
#               Périmètre              Nature       Date    Heures  \
# 0  Auvergne-Rhône-Alpes  Données temps réel 2025-01-01  00:00:00
# 2  Auvergne-Rhône-Alpes  Données temps réel 2025-01-01  00:30:00
# 4  Auvergne-Rhône-Alpes  Données temps réel 2025-01-01  01:00:00
# 6  Auvergne-Rhône-Alpes  Données temps réel 2025-01-01  01:30:00
# 8  Auvergne-Rhône-Alpes  Données temps réel 2025-01-01  02:00:00
#
#    Consommation  Thermique  Nucléaire  Eolien  Solaire  Hydraulique  ...  \
# 0        9002.0      134.0    11017.0   118.0      0.0       2609.0  ...
# 2        8940.0      133.0    10733.0   137.0      0.0       2454.0  ...
# 4        8802.0      126.0    10137.0   151.0      0.0       2319.0  ...
# 6        8718.0      125.0     9573.0   154.0      0.0       2511.0  ...
# 8        8719.0      126.0     9603.0   164.0      0.0       2500.0  ...
#
#    TCO Nucléaire (%)  TCH Nucléaire (%) TCO Eolien (%) TCH Eolien (%)  \
# 0             122.38              81.19           1.31          15.92
# 2             120.06              79.09           1.53          18.49
# 4             115.17              74.70           1.72          20.38
# 6             109.81              70.55           1.77          20.78
# 8             110.14              70.77           1.88          22.13
#
#   TCO Solaire (%) TCH Solaire (%)  TCO Hydraulique (%) TCH Hydraulique (%)  \
# 0             0.0             0.0                28.98               22.88
# 2             0.0             0.0                27.45               21.52
# 4             0.0             0.0                26.35               20.34
# 6             0.0             0.0                28.80               22.02
# 8             0.0             0.0                28.67               21.93
#
#   TCO Bioénergies (%) TCH Bioénergies (%)
# 0                0.44               21.16
# 2                0.45               21.16
# 4                0.45               21.16
# 6                0.46               21.16
# 8                0.46               21.16
#
# [5 rows x 67 columns]

# %%
print(df_all.info())
print(df_all.describe())
print(df_all.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85514 entries, 0 to 171022
# Data columns (total 67 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Périmètre                                                            85514 non-null  object
#  1   Nature                                                               85510 non-null  object
#  2   Date                                                                 85510 non-null  datetime64[ns]
#  3   Heures                                                               85510 non-null  object
#  4   Consommation                                                         85510 non-null  float64
#  5   Thermique                                                            85510 non-null  float64
#  6   Nucléaire                                                            85510 non-null  float64
#  7   Eolien                                                               85510 non-null  float64
#  8   Solaire                                                              85510 non-null  float64
#  9   Hydraulique                                                          85510 non-null  float64
#  10  Pompage                                                              85510 non-null  float64
#  11  Bioénergies                                                          85510 non-null  float64
#  12  Stockage batterie                                                    85510 non-null  object
#  13  Déstockage batterie                                                  85510 non-null  object
#  14  Eolien terrestre                                                     85510 non-null  object
#  15  Eolien offshore                                                      85510 non-null  object
#  16  Ech. physiques                                                       85510 non-null  float64
#  17  Flux physiques d'Auvergne-Rhône-Alpes vers Auvergne-Rhône-Alpes      85510 non-null  object
#  18  Flux physiques de Bourgogne-Franche-Comté vers Auvergne-Rhône-Alpes  85462 non-null  object
#  19  Flux physiques de Bretagne vers Auvergne-Rhône-Alpes                 85510 non-null  object
#  20  Flux physiques de Centre-Val de Loire vers Auvergne-Rhône-Alpes      85462 non-null  object
#  21  Flux physiques de Grand-Est vers Auvergne-Rhône-Alpes                85510 non-null  object
#  22  Flux physiques de Hauts-de-France vers Auvergne-Rhône-Alpes          85510 non-null  object
#  23  Flux physiques d'Ile-de-France vers Auvergne-Rhône-Alpes             85510 non-null  object
#  24  Flux physiques de Normandie vers Auvergne-Rhône-Alpes                85510 non-null  object
#  25  Flux physiques de Nouvelle-Aquitaine vers Auvergne-Rhône-Alpes       85462 non-null  object
#  26  Flux physiques d'Occitanie vers Auvergne-Rhône-Alpes                 85462 non-null  object
#  27  Flux physiques de Pays-de-la-Loire vers Auvergne-Rhône-Alpes         85510 non-null  object
#  28  Flux physiques de PACA vers Auvergne-Rhône-Alpes                     85462 non-null  object
#  29  Flux physiques de Auvergne-Rhône-Alpes vers Auvergne-Rhône-Alpes     85510 non-null  object
#  30  Flux physiques de Auvergne-Rhône-Alpes vers Bourgogne-Franche-Comté  85510 non-null  object
#  31  Flux physiques de Auvergne-Rhône-Alpes vers Bretagne                 85510 non-null  object
#  32  Flux physiques de Auvergne-Rhône-Alpes vers Centre-Val de Loire      85510 non-null  object
#  33  Flux physiques de Auvergne-Rhône-Alpes vers Grand-Est                85510 non-null  object
#  34  Flux physiques de Auvergne-Rhône-Alpes vers Hauts-de-France          85510 non-null  object
#  35  Flux physiques de Auvergne-Rhône-Alpes vers Ile-de-France            85510 non-null  object
#  36  Flux physiques de Auvergne-Rhône-Alpes vers Normandie                85510 non-null  object
#  37  Flux physiques de Auvergne-Rhône-Alpes vers Nouvelle-Aquitaine       85510 non-null  object
#  38  Flux physiques de Auvergne-Rhône-Alpes vers Occitanie                85510 non-null  object
#  39  Flux physiques de Auvergne-Rhône-Alpes vers Pays-de-la-Loire         85510 non-null  object
#  40  Flux physiques de Auvergne-Rhône-Alpes vers PACA                     85510 non-null  object
#  41  Flux physiques Allemagne vers Auvergne-Rhône-Alpes                   85510 non-null  object
#  42  Flux physiques Belgique vers Auvergne-Rhône-Alpes                    85510 non-null  object
#  43  Flux physiques Espagne vers Auvergne-Rhône-Alpes                     85510 non-null  object
#  44  Flux physiques Italie vers Auvergne-Rhône-Alpes                      85462 non-null  object
#  45  Flux physiques Luxembourg vers Auvergne-Rhône-Alpes                  85510 non-null  object
#  46  Flux physiques Royaume-Uni vers Auvergne-Rhône-Alpes                 85510 non-null  object
#  47  Flux physiques Suisse vers Auvergne-Rhône-Alpes                      85462 non-null  object
#  48  Flux physiques de Auvergne-Rhône-Alpes vers Allemagne                85510 non-null  object
#  49  Flux physiques de Auvergne-Rhône-Alpes vers Belgique                 85510 non-null  object
#  50  Flux physiques de Auvergne-Rhône-Alpes vers Espagne                  85510 non-null  object
#  51  Flux physiques de Auvergne-Rhône-Alpes vers Italie                   85510 non-null  object
#  52  Flux physiques de Auvergne-Rhône-Alpes vers Luxembourg               85510 non-null  object
#  53  Flux physiques de Auvergne-Rhône-Alpes vers Royaume-Uni              85510 non-null  object
#  54  Flux physiques de Auvergne-Rhône-Alpes vers Suisse                   85510 non-null  object
#  55  TCO Thermique (%)                                                    85507 non-null  float64
#  56  TCH Thermique (%)                                                    85510 non-null  float64
#  57  TCO Nucléaire (%)                                                    85507 non-null  float64
#  58  TCH Nucléaire (%)                                                    85510 non-null  float64
#  59  TCO Eolien (%)                                                       85507 non-null  float64
#  60  TCH Eolien (%)                                                       85510 non-null  float64
#  61  TCO Solaire (%)                                                      85507 non-null  float64
#  62  TCH Solaire (%)                                                      85510 non-null  float64
#  63  TCO Hydraulique (%)                                                  85507 non-null  float64
#  64  TCH Hydraulique (%)                                                  85510 non-null  float64
#  65  TCO Bioénergies (%)                                                  85507 non-null  float64
#  66  TCH Bioénergies (%)                                                  85510 non-null  float64
# dtypes: datetime64[ns](1), float64(21), object(45)
# memory usage: 44.4+ MB
# None
#                                 Date  Consommation     Thermique  \
# count                          85510  85510.000000  85510.000000
# mean   2023-06-10 05:30:06.020348416   7090.458426    197.800351
# min              2021-01-01 00:00:00      0.000000      0.000000
# 25%              2022-03-22 00:00:00   5982.000000     13.000000
# 50%              2023-06-10 00:00:00   6924.000000    122.000000
# 75%              2024-08-29 00:00:00   7987.000000    376.000000
# max              2025-11-17 00:00:00  13974.000000    724.000000
# std                              NaN   1454.799644    211.922889
#
#           Nucléaire        Eolien       Solaire   Hydraulique       Pompage  \
# count  85510.000000  85510.000000  85510.000000  85510.000000  85510.000000
# mean    9177.721284    161.476447    297.119986   3065.147258   -427.274436
# min        0.000000      0.000000      0.000000      0.000000  -2580.000000
# 25%     7828.000000     62.000000      0.000000   2118.000000   -810.000000
# 50%     9094.000000    134.000000     11.000000   2949.000000    -23.000000
# 75%    10578.000000    233.000000    485.000000   3831.000000    -13.000000
# max    13568.000000    628.000000   2465.000000   8468.000000      5.000000
# std     1849.332547    121.437666    460.374909   1261.685798    570.129202
#
#         Bioénergies  Ech. physiques  ...  TCO Nucléaire (%)  \
# count  85510.000000    85510.000000  ...       85507.000000
# mean     106.304140    -5487.943469  ...         131.638850
# min        0.000000   -12787.000000  ...          57.880000
# 25%      100.000000    -6938.000000  ...         114.210000
# 50%      113.000000    -5510.000000  ...         128.500000
# 75%      121.000000    -4103.000000  ...         146.430000
# max      143.000000     1270.000000  ...         317.050000
# std       21.947209     2027.123487  ...          24.882077
#
#        TCH Nucléaire (%)  TCO Eolien (%)  TCH Eolien (%)  TCO Solaire (%)  \
# count       85510.000000    85507.000000    85510.000000     85507.000000
# mean           67.632435        2.314810       22.961517         4.277683
# min             0.000000        0.000000        0.000000         0.000000
# 25%            57.690000        0.900000        8.850000         0.000000
# 50%            67.020000        1.900000       18.950000         0.150000
# 75%            77.950000        3.320000       33.200000         6.715000
# max            99.990000       12.380000       89.620000        42.530000
# std            13.628113        1.766984       17.322465         6.778875
#
#        TCH Solaire (%)  TCO Hydraulique (%)  TCH Hydraulique (%)  \
# count     85510.000000         85507.000000         85510.000000
# mean         15.155397            43.760613            26.721145
# min           0.000000             8.470000             0.000000
# 25%           0.000000            30.910000            18.480000
# 50%           0.450000            41.850000            25.730000
# 75%          26.400000            54.820000            33.340000
# max         110.390000           165.570000            73.300000
# std          22.255703            17.144778            10.986015
#
#        TCO Bioénergies (%)  TCH Bioénergies (%)
# count         85507.000000         85510.000000
# mean              1.561482            55.537985
# min               0.160000             0.000000
# 25%               1.250000            51.870000
# 50%               1.550000            59.260000
# 75%               1.860000            63.490000
# max               5.480000            73.820000
# std               0.454591            11.646476
#
# [8 rows x 22 columns]
# (85514, 67)
