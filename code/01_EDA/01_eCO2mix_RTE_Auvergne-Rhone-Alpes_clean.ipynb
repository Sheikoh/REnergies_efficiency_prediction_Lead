# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

# %% [markdown]
# # Import dataset

# %%
# Chargement API KEYS
load_dotenv()

API_KEY_S3 = os.environ["API_KEY_S3"]
API_SECRET_KEY_S3 = os.environ["API_SECRET_KEY_S3"]

bucket_name = "renergies99-lead-bucket"
s3_prefix = "public"

# %%
df = pd.read_csv(
    "s3://renergies99-lead-bucket/public/prod/eCO2mix_RTE_Auvergne-Rhone-Alpes.csv",
    index_col=0,
    storage_options={
        "key": API_KEY_S3,
        "secret": API_SECRET_KEY_S3,
    }
)
# Out:
# C:\Users\jean-\AppData\Local\Temp\ipykernel_30596\4158531870.py:1: DtypeWarning: Columns (12,13,14,15,18,20,25,26,28,30,32,37,38,40,44,47,51,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
df.head()
# Out:
#                                   Nature        Date    Heures  Consommation  \
# Périmètre
# Auvergne-Rhône-Alpes  Données temps réel  2025-01-01  00:00:00        9002.0
# Auvergne-Rhône-Alpes  Données temps réel  2025-01-01  00:30:00        8940.0
# Auvergne-Rhône-Alpes  Données temps réel  2025-01-01  01:00:00        8802.0
# Auvergne-Rhône-Alpes  Données temps réel  2025-01-01  01:30:00        8718.0
# Auvergne-Rhône-Alpes  Données temps réel  2025-01-01  02:00:00        8719.0
#
#                       Thermique  Nucléaire  Eolien  Solaire  Hydraulique  \
# Périmètre
# Auvergne-Rhône-Alpes      134.0    11017.0   118.0      0.0       2609.0
# Auvergne-Rhône-Alpes      133.0    10733.0   137.0      0.0       2454.0
# Auvergne-Rhône-Alpes      126.0    10137.0   151.0      0.0       2319.0
# Auvergne-Rhône-Alpes      125.0     9573.0   154.0      0.0       2511.0
# Auvergne-Rhône-Alpes      126.0     9603.0   164.0      0.0       2500.0
#
#                       Pompage  ...  TCO Nucléaire (%) TCH Nucléaire (%)  \
# Périmètre                      ...
# Auvergne-Rhône-Alpes  -1301.0  ...             122.38             81.19
# Auvergne-Rhône-Alpes  -1456.0  ...             120.06             79.09
# Auvergne-Rhône-Alpes  -1459.0  ...             115.17             74.70
# Auvergne-Rhône-Alpes  -1455.0  ...             109.81             70.55
# Auvergne-Rhône-Alpes  -1455.0  ...             110.14             70.77
#
#                      TCO Eolien (%) TCH Eolien (%) TCO Solaire (%)  \
# Périmètre
# Auvergne-Rhône-Alpes           1.31          15.92             0.0
# Auvergne-Rhône-Alpes           1.53          18.49             0.0
# Auvergne-Rhône-Alpes           1.72          20.38             0.0
# Auvergne-Rhône-Alpes           1.77          20.78             0.0
# Auvergne-Rhône-Alpes           1.88          22.13             0.0
#
#                       TCH Solaire (%) TCO Hydraulique (%) TCH Hydraulique (%)  \
# Périmètre
# Auvergne-Rhône-Alpes              0.0               28.98               22.88
# Auvergne-Rhône-Alpes              0.0               27.45               21.52
# Auvergne-Rhône-Alpes              0.0               26.35               20.34
# Auvergne-Rhône-Alpes              0.0               28.80               22.02
# Auvergne-Rhône-Alpes              0.0               28.67               21.93
#
#                      TCO Bioénergies (%) TCH Bioénergies (%)
# Périmètre
# Auvergne-Rhône-Alpes                0.44               21.16
# Auvergne-Rhône-Alpes                0.45               21.16
# Auvergne-Rhône-Alpes                0.45               21.16
# Auvergne-Rhône-Alpes                0.46               21.16
# Auvergne-Rhône-Alpes                0.46               21.16
#
# [5 rows x 66 columns]

# %%
df.shape
# Out:
# (85514, 66)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85514 entries, Auvergne-Rhône-Alpes to RTE ne pourra être tenu responsable de l'usage qui pourrait être fait des données mises à disposition, ni en cas de prévisions qui se révèleraient imprécises.
# Data columns (total 66 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Nature                                                               85510 non-null  object
#  1   Date                                                                 85510 non-null  object
#  2   Heures                                                               85510 non-null  object
#  3   Consommation                                                         85510 non-null  float64
#  4   Thermique                                                            85510 non-null  float64
#  5   Nucléaire                                                            85510 non-null  float64
#  6   Eolien                                                               85510 non-null  float64
#  7   Solaire                                                              85510 non-null  float64
#  8   Hydraulique                                                          85510 non-null  float64
#  9   Pompage                                                              85510 non-null  float64
#  10  Bioénergies                                                          85510 non-null  float64
#  11  Stockage batterie                                                    85510 non-null  object
#  12  Déstockage batterie                                                  85510 non-null  object
#  13  Eolien terrestre                                                     85510 non-null  object
#  14  Eolien offshore                                                      85510 non-null  object
#  15  Ech. physiques                                                       85510 non-null  float64
#  16  Flux physiques d'Auvergne-Rhône-Alpes vers Auvergne-Rhône-Alpes      85510 non-null  object
#  17  Flux physiques de Bourgogne-Franche-Comté vers Auvergne-Rhône-Alpes  85462 non-null  object
#  18  Flux physiques de Bretagne vers Auvergne-Rhône-Alpes                 85510 non-null  object
#  19  Flux physiques de Centre-Val de Loire vers Auvergne-Rhône-Alpes      85462 non-null  object
#  20  Flux physiques de Grand-Est vers Auvergne-Rhône-Alpes                85510 non-null  object
#  21  Flux physiques de Hauts-de-France vers Auvergne-Rhône-Alpes          85510 non-null  object
#  22  Flux physiques d'Ile-de-France vers Auvergne-Rhône-Alpes             85510 non-null  object
#  23  Flux physiques de Normandie vers Auvergne-Rhône-Alpes                85510 non-null  object
#  24  Flux physiques de Nouvelle-Aquitaine vers Auvergne-Rhône-Alpes       85462 non-null  object
#  25  Flux physiques d'Occitanie vers Auvergne-Rhône-Alpes                 85462 non-null  object
#  26  Flux physiques de Pays-de-la-Loire vers Auvergne-Rhône-Alpes         85510 non-null  object
#  27  Flux physiques de PACA vers Auvergne-Rhône-Alpes                     85462 non-null  object
#  28  Flux physiques de Auvergne-Rhône-Alpes vers Auvergne-Rhône-Alpes     85510 non-null  object
#  29  Flux physiques de Auvergne-Rhône-Alpes vers Bourgogne-Franche-Comté  85510 non-null  object
#  30  Flux physiques de Auvergne-Rhône-Alpes vers Bretagne                 85510 non-null  object
#  31  Flux physiques de Auvergne-Rhône-Alpes vers Centre-Val de Loire      85510 non-null  object
#  32  Flux physiques de Auvergne-Rhône-Alpes vers Grand-Est                85510 non-null  object
#  33  Flux physiques de Auvergne-Rhône-Alpes vers Hauts-de-France          85510 non-null  object
#  34  Flux physiques de Auvergne-Rhône-Alpes vers Ile-de-France            85510 non-null  object
#  35  Flux physiques de Auvergne-Rhône-Alpes vers Normandie                85510 non-null  object
#  36  Flux physiques de Auvergne-Rhône-Alpes vers Nouvelle-Aquitaine       85510 non-null  object
#  37  Flux physiques de Auvergne-Rhône-Alpes vers Occitanie                85510 non-null  object
#  38  Flux physiques de Auvergne-Rhône-Alpes vers Pays-de-la-Loire         85510 non-null  object
#  39  Flux physiques de Auvergne-Rhône-Alpes vers PACA                     85510 non-null  object
#  40  Flux physiques Allemagne vers Auvergne-Rhône-Alpes                   85510 non-null  object
#  41  Flux physiques Belgique vers Auvergne-Rhône-Alpes                    85510 non-null  object
#  42  Flux physiques Espagne vers Auvergne-Rhône-Alpes                     85510 non-null  object
#  43  Flux physiques Italie vers Auvergne-Rhône-Alpes                      85462 non-null  object
#  44  Flux physiques Luxembourg vers Auvergne-Rhône-Alpes                  85510 non-null  object
#  45  Flux physiques Royaume-Uni vers Auvergne-Rhône-Alpes                 85510 non-null  object
#  46  Flux physiques Suisse vers Auvergne-Rhône-Alpes                      85462 non-null  object
#  47  Flux physiques de Auvergne-Rhône-Alpes vers Allemagne                85510 non-null  object
#  48  Flux physiques de Auvergne-Rhône-Alpes vers Belgique                 85510 non-null  object
#  49  Flux physiques de Auvergne-Rhône-Alpes vers Espagne                  85510 non-null  object
#  50  Flux physiques de Auvergne-Rhône-Alpes vers Italie                   85510 non-null  object
#  51  Flux physiques de Auvergne-Rhône-Alpes vers Luxembourg               85510 non-null  object
#  52  Flux physiques de Auvergne-Rhône-Alpes vers Royaume-Uni              85510 non-null  object
#  53  Flux physiques de Auvergne-Rhône-Alpes vers Suisse                   85510 non-null  object
#  54  TCO Thermique (%)                                                    85507 non-null  float64
#  55  TCH Thermique (%)                                                    85510 non-null  float64
#  56  TCO Nucléaire (%)                                                    85507 non-null  float64
#  57  TCH Nucléaire (%)                                                    85510 non-null  float64
#  58  TCO Eolien (%)                                                       85507 non-null  float64
#  59  TCH Eolien (%)                                                       85510 non-null  float64
#  60  TCO Solaire (%)                                                      85507 non-null  float64
#  61  TCH Solaire (%)                                                      85510 non-null  float64
#  62  TCO Hydraulique (%)                                                  85507 non-null  float64
#  63  TCH Hydraulique (%)                                                  85510 non-null  float64
#  64  TCO Bioénergies (%)                                                  85507 non-null  float64
#  65  TCH Bioénergies (%)                                                  85510 non-null  float64
# dtypes: float64(21), object(45)
# memory usage: 43.7+ MB

# %%
df.describe(include="all")
# Out:
#                      Nature        Date    Heures  Consommation     Thermique  \
# count                 85510       85510     85510  85510.000000  85510.000000
# unique                    3        1782        48           NaN           NaN
# top     Données définitives  2025-01-01  00:00:00           NaN           NaN
# freq                  52560          48      1782           NaN           NaN
# mean                    NaN         NaN       NaN   7090.458426    197.800351
# std                     NaN         NaN       NaN   1454.799644    211.922889
# min                     NaN         NaN       NaN      0.000000      0.000000
# 25%                     NaN         NaN       NaN   5982.000000     13.000000
# 50%                     NaN         NaN       NaN   6924.000000    122.000000
# 75%                     NaN         NaN       NaN   7987.000000    376.000000
# max                     NaN         NaN       NaN  13974.000000    724.000000
#
#            Nucléaire        Eolien       Solaire   Hydraulique       Pompage  \
# count   85510.000000  85510.000000  85510.000000  85510.000000  85510.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean     9177.721284    161.476447    297.119986   3065.147258   -427.274436
# std      1849.332547    121.437666    460.374909   1261.685798    570.129202
# min         0.000000      0.000000      0.000000      0.000000  -2580.000000
# 25%      7828.000000     62.000000      0.000000   2118.000000   -810.000000
# 50%      9094.000000    134.000000     11.000000   2949.000000    -23.000000
# 75%     10578.000000    233.000000    485.000000   3831.000000    -13.000000
# max     13568.000000    628.000000   2465.000000   8468.000000      5.000000
#
#         ...  TCO Nucléaire (%)  TCH Nucléaire (%)  TCO Eolien (%)  \
# count   ...       85507.000000       85510.000000    85507.000000
# unique  ...                NaN                NaN             NaN
# top     ...                NaN                NaN             NaN
# freq    ...                NaN                NaN             NaN
# mean    ...         131.638850          67.632435        2.314810
# std     ...          24.882077          13.628113        1.766984
# min     ...          57.880000           0.000000        0.000000
# 25%     ...         114.210000          57.690000        0.900000
# 50%     ...         128.500000          67.020000        1.900000
# 75%     ...         146.430000          77.950000        3.320000
# max     ...         317.050000          99.990000       12.380000
#
#         TCH Eolien (%)  TCO Solaire (%)  TCH Solaire (%) TCO Hydraulique (%)  \
# count     85510.000000     85507.000000     85510.000000        85507.000000
# unique             NaN              NaN              NaN                 NaN
# top                NaN              NaN              NaN                 NaN
# freq               NaN              NaN              NaN                 NaN
# mean         22.961517         4.277683        15.155397           43.760613
# std          17.322465         6.778875        22.255703           17.144778
# min           0.000000         0.000000         0.000000            8.470000
# 25%           8.850000         0.000000         0.000000           30.910000
# 50%          18.950000         0.150000         0.450000           41.850000
# 75%          33.200000         6.715000        26.400000           54.820000
# max          89.620000        42.530000       110.390000          165.570000
#
#        TCH Hydraulique (%) TCO Bioénergies (%) TCH Bioénergies (%)
# count         85510.000000        85507.000000        85510.000000
# unique                 NaN                 NaN                 NaN
# top                    NaN                 NaN                 NaN
# freq                   NaN                 NaN                 NaN
# mean             26.721145            1.561482           55.537985
# std              10.986015            0.454591           11.646476
# min               0.000000            0.160000            0.000000
# 25%              18.480000            1.250000           51.870000
# 50%              25.730000            1.550000           59.260000
# 75%              33.340000            1.860000           63.490000
# max              73.300000            5.480000           73.820000
#
# [11 rows x 66 columns]

# %% [markdown]
# # Vue générale

# %%
# Nombre de  valeurs manquantes
valeurs_manquantes = df.isna().sum()
valeurs_manquantes
# Out:
# Nature                 4
# Date                   4
# Heures                 4
# Consommation           4
# Thermique              4
#                       ..
# TCH Solaire (%)        4
# TCO Hydraulique (%)    7
# TCH Hydraulique (%)    4
# TCO Bioénergies (%)    7
# TCH Bioénergies (%)    4
# Length: 66, dtype: int64

# %%
# Pourcentage de valeurs manquantes
valeurs_manquantes_pourcent = (df.isna().sum() / df.shape[0]) * 100
valeurs_manquantes_pourcent
# Out:
# Nature                 0.004678
# Date                   0.004678
# Heures                 0.004678
# Consommation           0.004678
# Thermique              0.004678
#                          ...
# TCH Solaire (%)        0.004678
# TCO Hydraulique (%)    0.008186
# TCH Hydraulique (%)    0.004678
# TCO Bioénergies (%)    0.008186
# TCH Bioénergies (%)    0.004678
# Length: 66, dtype: float64

# %%
valeurs_manquantes_graph = valeurs_manquantes[valeurs_manquantes > 0].sort_values(ascending=False)

plt.figure(figsize=(10, 5))
# Prise en charge si valeurs manquetes à 0
if valeurs_manquantes_graph.empty:
    ax = plt.gca()
    ax.text(0.5, 0.5, "Aucune valeur manquante",
            ha="center", va="center", fontsize=12)
    ax.axis("off")
else:
    valeurs_manquantes_graph.plot(kind="bar")
    plt.title("Valeurs manquantes par colonne")
    plt.ylabel("Nombre de valeurs manquantes")
    plt.xticks(rotation=45, ha="right")

plt.show()

# %%
# Vérification valeurs numériques float uniques
numeric_float = df.select_dtypes('float64')

for col in numeric_float.columns:
  print(f"Colonne {col} : ", numeric_float[col].nunique())
# Out:
# Colonne Consommation :  7098
# Colonne Thermique :  725
# Colonne Nucléaire :  8420
# Colonne Eolien :  610
# Colonne Solaire :  2274
# Colonne Hydraulique :  6402
# Colonne Pompage :  2320
# Colonne Bioénergies :  102
# Colonne Ech. physiques :  10054
# Colonne TCO Thermique (%) :  997
# Colonne TCH Thermique (%) :  3835
# Colonne TCO Nucléaire (%) :  12241
# Colonne TCH Nucléaire (%) :  6332
# Colonne TCO Eolien (%) :  998
# Colonne TCH Eolien (%) :  3931
# Colonne TCO Solaire (%) :  3270
# Colonne TCH Solaire (%) :  7010
# Colonne TCO Hydraulique (%) :  8216
# Colonne TCH Hydraulique (%) :  5651
# Colonne TCO Bioénergies (%) :  300
# Colonne TCH Bioénergies (%) :  425

# %%
# Vérification valeurs numériques int uniques
numeric_int = df.select_dtypes('int64')

for col in numeric_int.columns:
  print(f"Colonne {col} : ", numeric_int[col].nunique())

# %%
# Vérification valeurs non numériques float uniques
non_numeric = df.select_dtypes('object')

for col in non_numeric.columns:
  print(f"Colonne {col} : ", non_numeric[col].nunique())
# Out:
# Colonne Nature :  3
# Colonne Date :  1782
# Colonne Heures :  48
# Colonne Stockage batterie :  23
# Colonne Déstockage batterie :  24
# Colonne Eolien terrestre :  4
# Colonne Eolien offshore :  4
# Colonne Flux physiques d'Auvergne-Rhône-Alpes vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Bourgogne-Franche-Comté vers Auvergne-Rhône-Alpes :  5854
# Colonne Flux physiques de Bretagne vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Centre-Val de Loire vers Auvergne-Rhône-Alpes :  2978
# Colonne Flux physiques de Grand-Est vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Hauts-de-France vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques d'Ile-de-France vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Normandie vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Nouvelle-Aquitaine vers Auvergne-Rhône-Alpes :  631
# Colonne Flux physiques d'Occitanie vers Auvergne-Rhône-Alpes :  1856
# Colonne Flux physiques de Pays-de-la-Loire vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de PACA vers Auvergne-Rhône-Alpes :  1150
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Bourgogne-Franche-Comté :  10439
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Bretagne :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Centre-Val de Loire :  2330
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Grand-Est :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Hauts-de-France :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Ile-de-France :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Normandie :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Nouvelle-Aquitaine :  1362
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Occitanie :  14883
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Pays-de-la-Loire :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers PACA :  3125
# Colonne Flux physiques Allemagne vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Belgique vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Espagne vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Italie vers Auvergne-Rhône-Alpes :  1465
# Colonne Flux physiques Luxembourg vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Royaume-Uni vers Auvergne-Rhône-Alpes :  1
# Colonne Flux physiques Suisse vers Auvergne-Rhône-Alpes :  2495
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Allemagne :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Belgique :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Espagne :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Italie :  11316
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Luxembourg :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Royaume-Uni :  1
# Colonne Flux physiques de Auvergne-Rhône-Alpes vers Suisse :  7293

# %% [markdown]
# # Cleaning

# %%
df.replace(["ND", "n.d", "Na", "na", "-", ""], np.nan, inplace=True)
# Out:
# C:\Users\jean-\AppData\Local\Temp\ipykernel_30596\2168416036.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(["ND", "n.d", "Na", "na", "-", ""], np.nan, inplace=True)

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df.shape
# Out:
# (85514, 66)

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85514 entries, Auvergne-Rhône-Alpes to RTE ne pourra être tenu responsable de l'usage qui pourrait être fait des données mises à disposition, ni en cas de prévisions qui se révèleraient imprécises.
# Data columns (total 66 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   nature                                                               85510 non-null  object
#  1   date                                                                 85510 non-null  object
#  2   heures                                                               85510 non-null  object
#  3   consommation                                                         85510 non-null  float64
#  4   thermique                                                            85510 non-null  float64
#  5   nucléaire                                                            85510 non-null  float64
#  6   eolien                                                               85510 non-null  float64
#  7   solaire                                                              85510 non-null  float64
#  8   hydraulique                                                          85510 non-null  float64
#  9   pompage                                                              85510 non-null  float64
#  10  bioénergies                                                          85510 non-null  float64
#  11  stockage_batterie                                                    85509 non-null  object
#  12  déstockage_batterie                                                  85509 non-null  object
#  13  eolien_terrestre                                                     70127 non-null  object
#  14  eolien_offshore                                                      70127 non-null  object
#  15  ech._physiques                                                       85510 non-null  float64
#  16  flux_physiques_d'auvergne-rhône-alpes_vers_auvergne-rhône-alpes      0 non-null      float64
#  17  flux_physiques_de_bourgogne-franche-comté_vers_auvergne-rhône-alpes  32902 non-null  object
#  18  flux_physiques_de_bretagne_vers_auvergne-rhône-alpes                 0 non-null      float64
#  19  flux_physiques_de_centre-val_de_loire_vers_auvergne-rhône-alpes      32902 non-null  object
#  20  flux_physiques_de_grand-est_vers_auvergne-rhône-alpes                0 non-null      float64
#  21  flux_physiques_de_hauts-de-france_vers_auvergne-rhône-alpes          0 non-null      float64
#  22  flux_physiques_d'ile-de-france_vers_auvergne-rhône-alpes             0 non-null      float64
#  23  flux_physiques_de_normandie_vers_auvergne-rhône-alpes                0 non-null      float64
#  24  flux_physiques_de_nouvelle-aquitaine_vers_auvergne-rhône-alpes       32902 non-null  object
#  25  flux_physiques_d'occitanie_vers_auvergne-rhône-alpes                 32902 non-null  object
#  26  flux_physiques_de_pays-de-la-loire_vers_auvergne-rhône-alpes         0 non-null      float64
#  27  flux_physiques_de_paca_vers_auvergne-rhône-alpes                     32902 non-null  object
#  28  flux_physiques_de_auvergne-rhône-alpes_vers_auvergne-rhône-alpes     0 non-null      float64
#  29  flux_physiques_de_auvergne-rhône-alpes_vers_bourgogne-franche-comté  67941 non-null  object
#  30  flux_physiques_de_auvergne-rhône-alpes_vers_bretagne                 0 non-null      float64
#  31  flux_physiques_de_auvergne-rhône-alpes_vers_centre-val_de_loire      67941 non-null  object
#  32  flux_physiques_de_auvergne-rhône-alpes_vers_grand-est                0 non-null      float64
#  33  flux_physiques_de_auvergne-rhône-alpes_vers_hauts-de-france          0 non-null      float64
#  34  flux_physiques_de_auvergne-rhône-alpes_vers_ile-de-france            0 non-null      float64
#  35  flux_physiques_de_auvergne-rhône-alpes_vers_normandie                0 non-null      float64
#  36  flux_physiques_de_auvergne-rhône-alpes_vers_nouvelle-aquitaine       67941 non-null  object
#  37  flux_physiques_de_auvergne-rhône-alpes_vers_occitanie                67941 non-null  object
#  38  flux_physiques_de_auvergne-rhône-alpes_vers_pays-de-la-loire         0 non-null      float64
#  39  flux_physiques_de_auvergne-rhône-alpes_vers_paca                     67941 non-null  object
#  40  flux_physiques_allemagne_vers_auvergne-rhône-alpes                   0 non-null      float64
#  41  flux_physiques_belgique_vers_auvergne-rhône-alpes                    0 non-null      float64
#  42  flux_physiques_espagne_vers_auvergne-rhône-alpes                     0 non-null      float64
#  43  flux_physiques_italie_vers_auvergne-rhône-alpes                      32902 non-null  object
#  44  flux_physiques_luxembourg_vers_auvergne-rhône-alpes                  0 non-null      float64
#  45  flux_physiques_royaume-uni_vers_auvergne-rhône-alpes                 0 non-null      float64
#  46  flux_physiques_suisse_vers_auvergne-rhône-alpes                      32902 non-null  object
#  47  flux_physiques_de_auvergne-rhône-alpes_vers_allemagne                0 non-null      float64
#  48  flux_physiques_de_auvergne-rhône-alpes_vers_belgique                 0 non-null      float64
#  49  flux_physiques_de_auvergne-rhône-alpes_vers_espagne                  0 non-null      float64
#  50  flux_physiques_de_auvergne-rhône-alpes_vers_italie                   67941 non-null  object
#  51  flux_physiques_de_auvergne-rhône-alpes_vers_luxembourg               0 non-null      float64
#  52  flux_physiques_de_auvergne-rhône-alpes_vers_royaume-uni              0 non-null      float64
#  53  flux_physiques_de_auvergne-rhône-alpes_vers_suisse                   67941 non-null  object
#  54  tco_thermique_(%)                                                    85507 non-null  float64
#  55  tch_thermique_(%)                                                    85510 non-null  float64
#  56  tco_nucléaire_(%)                                                    85507 non-null  float64
#  57  tch_nucléaire_(%)                                                    85510 non-null  float64
#  58  tco_eolien_(%)                                                       85507 non-null  float64
#  59  tch_eolien_(%)                                                       85510 non-null  float64
#  60  tco_solaire_(%)                                                      85507 non-null  float64
#  61  tch_solaire_(%)                                                      85510 non-null  float64
#  62  tco_hydraulique_(%)                                                  85507 non-null  float64
#  63  tch_hydraulique_(%)                                                  85510 non-null  float64
#  64  tco_bioénergies_(%)                                                  85507 non-null  float64
#  65  tch_bioénergies_(%)                                                  85510 non-null  float64
# dtypes: float64(45), object(21)
# memory usage: 43.7+ MB
# None
#        consommation     thermique     nucléaire        eolien       solaire  \
# count  85510.000000  85510.000000  85510.000000  85510.000000  85510.000000
# mean    7090.458426    197.800351   9177.721284    161.476447    297.119986
# std     1454.799644    211.922889   1849.332547    121.437666    460.374909
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     5982.000000     13.000000   7828.000000     62.000000      0.000000
# 50%     6924.000000    122.000000   9094.000000    134.000000     11.000000
# 75%     7987.000000    376.000000  10578.000000    233.000000    485.000000
# max    13974.000000    724.000000  13568.000000    628.000000   2465.000000
#
#         hydraulique       pompage   bioénergies  ech._physiques  \
# count  85510.000000  85510.000000  85510.000000    85510.000000
# mean    3065.147258   -427.274436    106.304140    -5487.943469
# std     1261.685798    570.129202     21.947209     2027.123487
# min        0.000000  -2580.000000      0.000000   -12787.000000
# 25%     2118.000000   -810.000000    100.000000    -6938.000000
# 50%     2949.000000    -23.000000    113.000000    -5510.000000
# 75%     3831.000000    -13.000000    121.000000    -4103.000000
# max     8468.000000      5.000000    143.000000     1270.000000
#
#        flux_physiques_d'auvergne-rhône-alpes_vers_auvergne-rhône-alpes  ...  \
# count                                                0.0                ...
# mean                                                 NaN                ...
# std                                                  NaN                ...
# min                                                  NaN                ...
# 25%                                                  NaN                ...
# 50%                                                  NaN                ...
# 75%                                                  NaN                ...
# max                                                  NaN                ...
#
#        tco_nucléaire_(%)  tch_nucléaire_(%)  tco_eolien_(%)  tch_eolien_(%)  \
# count       85507.000000       85510.000000    85507.000000    85510.000000
# mean          131.638850          67.632435        2.314810       22.961517
# std            24.882077          13.628113        1.766984       17.322465
# min            57.880000           0.000000        0.000000        0.000000
# 25%           114.210000          57.690000        0.900000        8.850000
# 50%           128.500000          67.020000        1.900000       18.950000
# 75%           146.430000          77.950000        3.320000       33.200000
# max           317.050000          99.990000       12.380000       89.620000
#
#        tco_solaire_(%)  tch_solaire_(%)  tco_hydraulique_(%)  \
# count     85507.000000     85510.000000         85507.000000
# mean          4.277683        15.155397            43.760613
# std           6.778875        22.255703            17.144778
# min           0.000000         0.000000             8.470000
# 25%           0.000000         0.000000            30.910000
# 50%           0.150000         0.450000            41.850000
# 75%           6.715000        26.400000            54.820000
# max          42.530000       110.390000           165.570000
#
#        tch_hydraulique_(%)  tco_bioénergies_(%)  tch_bioénergies_(%)
# count         85510.000000         85507.000000         85510.000000
# mean             26.721145             1.561482            55.537985
# std              10.986015             0.454591            11.646476
# min               0.000000             0.160000             0.000000
# 25%              18.480000             1.250000            51.870000
# 50%              25.730000             1.550000            59.260000
# 75%              33.340000             1.860000            63.490000
# max              73.300000             5.480000            73.820000
#
# [8 rows x 45 columns]

# %%
df.head()
# Out:
#                                   nature        date    heures  consommation  \
# Périmètre
# Auvergne-Rhône-Alpes  Données temps réel  2025-01-01  00:00:00        9002.0
# Auvergne-Rhône-Alpes  Données temps réel  2025-01-01  00:30:00        8940.0
# Auvergne-Rhône-Alpes  Données temps réel  2025-01-01  01:00:00        8802.0
# Auvergne-Rhône-Alpes  Données temps réel  2025-01-01  01:30:00        8718.0
# Auvergne-Rhône-Alpes  Données temps réel  2025-01-01  02:00:00        8719.0
#
#                       thermique  nucléaire  eolien  solaire  hydraulique  \
# Périmètre
# Auvergne-Rhône-Alpes      134.0    11017.0   118.0      0.0       2609.0
# Auvergne-Rhône-Alpes      133.0    10733.0   137.0      0.0       2454.0
# Auvergne-Rhône-Alpes      126.0    10137.0   151.0      0.0       2319.0
# Auvergne-Rhône-Alpes      125.0     9573.0   154.0      0.0       2511.0
# Auvergne-Rhône-Alpes      126.0     9603.0   164.0      0.0       2500.0
#
#                       pompage  ...  tco_nucléaire_(%) tch_nucléaire_(%)  \
# Périmètre                      ...
# Auvergne-Rhône-Alpes  -1301.0  ...             122.38             81.19
# Auvergne-Rhône-Alpes  -1456.0  ...             120.06             79.09
# Auvergne-Rhône-Alpes  -1459.0  ...             115.17             74.70
# Auvergne-Rhône-Alpes  -1455.0  ...             109.81             70.55
# Auvergne-Rhône-Alpes  -1455.0  ...             110.14             70.77
#
#                      tco_eolien_(%) tch_eolien_(%) tco_solaire_(%)  \
# Périmètre
# Auvergne-Rhône-Alpes           1.31          15.92             0.0
# Auvergne-Rhône-Alpes           1.53          18.49             0.0
# Auvergne-Rhône-Alpes           1.72          20.38             0.0
# Auvergne-Rhône-Alpes           1.77          20.78             0.0
# Auvergne-Rhône-Alpes           1.88          22.13             0.0
#
#                       tch_solaire_(%)  tco_hydraulique_(%)  \
# Périmètre
# Auvergne-Rhône-Alpes              0.0                28.98
# Auvergne-Rhône-Alpes              0.0                27.45
# Auvergne-Rhône-Alpes              0.0                26.35
# Auvergne-Rhône-Alpes              0.0                28.80
# Auvergne-Rhône-Alpes              0.0                28.67
#
#                      tch_hydraulique_(%)  tco_bioénergies_(%)  \
# Périmètre
# Auvergne-Rhône-Alpes               22.88                 0.44
# Auvergne-Rhône-Alpes               21.52                 0.45
# Auvergne-Rhône-Alpes               20.34                 0.45
# Auvergne-Rhône-Alpes               22.02                 0.46
# Auvergne-Rhône-Alpes               21.93                 0.46
#
#                      tch_bioénergies_(%)
# Périmètre
# Auvergne-Rhône-Alpes               21.16
# Auvergne-Rhône-Alpes               21.16
# Auvergne-Rhône-Alpes               21.16
# Auvergne-Rhône-Alpes               21.16
# Auvergne-Rhône-Alpes               21.16
#
# [5 rows x 66 columns]

# %%
# Écriture directe du DataFrame cleaned sur S3
df.to_csv(
    "s3://renergies99-lead-bucket/public/prod/eCO2mix_RTE_Auvergne-Rhone-Alpes_cleaned.csv",
    index=False,
    storage_options={
        "key": API_KEY_S3,
        "secret": API_SECRET_KEY_S3,
    },
)
