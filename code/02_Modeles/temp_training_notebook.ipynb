# %%
#----IMPORT LIBRAIRIES----

# %%
# %run train.py
# Out:
# Data collected
# Data cleaned
# Dataset shape : (1389, 83)
# Training in progress....
# ...
# 🏃 View run monumental-calf-225 at: https://renergies99lead-mlflow.hf.space/#/experiments/4/runs/99f6fdf69f2e4de3ba6e7042ead7f0c1
# 🧪 View experiment at: https://renergies99lead-mlflow.hf.space/#/experiments/4

# %%
input_example
# Out:
#       Moulins_temp  Moulins_feels_like  Moulins_pressure  Moulins_humidity  \
# 1213         19.68               19.66            1012.0              75.0
# 150          22.68               22.52            1023.0              58.0
# 575          29.63               28.35            1012.0              29.0
#
#       Moulins_dew_point  Moulins_clouds  Moulins_wind_speed  Moulins_wind_deg  \
# 1213              15.13            26.0                1.55             127.0
# 150               14.00            15.0                1.99             350.0
# 575                9.72             0.0                3.36              77.0
#
#       Moulins_Month  Moulins_apparent_zenith  ...  Nyons_Month  \
# 1213            5.0                35.092172  ...          5.0
# 150             6.0                31.831877  ...          6.0
# 575             8.0                39.532115  ...          8.0
#
#       Nyons_apparent_zenith  Nyons_zenith  Nyons_apparent_elevation  \
# ...

# %%
pipeline.predict(input_example)
# Out:
# array([46.30270343, 36.30807101, 41.56216325])
